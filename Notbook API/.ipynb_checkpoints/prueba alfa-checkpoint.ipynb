# %%
import matplotlib
import requests
import json
import pylab
import pandas as pd
import numpy as np
import io
from astropy.io import ascii
from astropy.table import Table
from astropy.io.votable import parse
from astropy.coordinates import SkyCoord
from astropy import units as u

# %%
def consulta_degree(ra,dec,radius,format,catalog):
    url = 'http://127.0.0.1:5000/radio-degree'
    params = {'ra':ra,'dec':dec,'radius':radius,'format':format,'catalog':catalog}
    r = requests.post(url, data=params)
    return r

# %%
r = consulta_degree(139.33444972,68.6350604,0.002777,'votable','ztf')

# %%
catalogos = r.json().keys()
print(catalogos)
# Out:
# dict_keys(['curve_ztf'])

# %%
#ascii.read(r.json()['curve_ps1']['190361393343891094'],format='csv', ) 
#pd.read_csv(r.json()['curve_ps1']['190361393343891094'],dtype=object)

# %%
r.json()['curve_ztf'].keys()
# Out:
# dict_keys(['841208100004637'])

# %%
votable = r.json()['curve_ztf']['841208100004637'].encode(encoding='UTF-8')
bio = io.BytesIO(votable)
votable = parse(bio)
tabla1 = votable.get_first_table()
tabla1
# Out:
# <Table length=72>
#       oid        expid          hjd         ... exptime airmass programid
#                                  d          ...    s
#      int64       int32        float64       ... float32 float32   int32
# --------------- -------- ------------------ ... ------- ------- ---------
# 841208100004637 46018800  2458214.688776107 ...    30.0   1.234         1
# 841208100004637 46320949 2458217.7100648363 ...    30.0    1.24         1
# 841208100004637 46324697  2458217.747550931 ...    30.0   1.272         1
# 841208100004637 46719099  2458221.691314015 ...    30.0   1.237         1
# 841208100004637 47015486 2458224.6549889613 ...    30.0   1.234         1
# 841208100004637 47315383  2458227.653765963 ...    30.0   1.234         1
# 841208100004637 47717678 2458231.6764597334 ...    30.0   1.244         1
# 841208100004637 48916305  2458243.661984175 ...    30.0   1.257         1
# 841208100004637 49221940 2458246.7181543303 ...    30.0    1.36         1
#             ...      ...                ... ...     ...     ...       ...
# 841208100004637 84726504  2458601.764417229 ...    30.0   1.407         1
# 841208100004637 85218248 2458606.6815532455 ...    30.0   1.274         1
# 841208100004637 86324037 2458617.7387783895 ...    30.0   1.464         1
# 841208100004637 88026105 2458634.7585781836 ...    30.0   1.756         1
# 841208100004637 88317128 2458637.6686786143 ...    30.0    1.42         1
# 841208100004637 88623570  2458640.732969081 ...    30.0   1.708         1
# 841208100004637 88924300 2458643.7401515967 ...    30.0   1.794         1
# 841208100004637 89221624 2458646.7132805665 ...    30.0   1.692         1
# 841208100004637 89522353  2458649.720455642 ...    30.0   1.776         1
# 841208100004637 90818601  2458662.682588756 ...    30.0   1.764         1

# %%
from astropy.io.votable import parse_single_table,from_table, writeto

# %%
table = parse_single_table(bio).to_table()

# %%
tablas = table.group_by('oid')
for group in tablas.groups:
    buf = io.BytesIO()
    votable = from_table(group)
    writeto(votable,buf)
    #print('#####################################################################################3')
    print(buf.getvalue())
# Out:
# #####################################################################################3
# b'<?xml version="1.0" encoding="utf-8"?>\n<!-- Produced with astropy.io.votable version 4.0.1.post1\n     http://www.astropy.org/ -->\n<VOTABLE version="1.4" xmlns="http://www.ivoa.net/xml/VOTable/v1.4" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:noNamespaceSchemaLocation="http://www.ivoa.net/xml/VOTable/v1.4">\n <RESOURCE type="results">\n  <TABLE>\n   <FIELD ID="oid" datatype="long" name="oid" ucd="meta.id">\n    <DESCRIPTION>\n     Object ID\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="expid" datatype="int" name="expid" ucd="meta.id;obs.exposure">\n    <DESCRIPTION>\n     Exposure ID\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="hjd" datatype="double" name="hjd" ucd="time.epoch" unit="d">\n    <DESCRIPTION>\n     Heliocentric Julian date (computed from mjd and the mean ra and\n     dec of the input catalog)\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="mjd" datatype="double" name="mjd" ucd="time.epoch;obs.exposure" unit="d">\n    <DESCRIPTION>\n     Modified Julian date\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="mag" datatype="float" name="mag" ucd="phot.mag;em.opt" unit="mag">\n    <DESCRIPTION>\n     Magnitude\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="magerr" datatype="float" name="magerr" ucd="stat.error;phot.mag;em.opt" unit="mag">\n    <DESCRIPTION>\n     Uncertainty in mag measurement. Includes correction to conform to\n     photometric repeatability RMS derived from "non-variable"\n     population.\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="catflags" datatype="int" name="catflags" ucd="meta.code">\n    <DESCRIPTION>\n     Catalog flags for source from PSF-fitting catalog\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="filtercode" arraysize="*" datatype="char" name="filtercode" ucd="instr.bandpass">\n    <DESCRIPTION>\n     Filter code (abbreviated name)\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="ra" datatype="double" name="ra" ucd="pos.eq.ra" unit="deg">\n    <DESCRIPTION>\n     Right Ascension of source\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="dec" datatype="double" name="dec" ucd="pos.eq.dec" unit="deg">\n    <DESCRIPTION>\n     Declination of source\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="chi" datatype="float" name="chi" ucd="stat.parameter">\n    <DESCRIPTION>\n     Chi-squared of source\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="sharp" datatype="float" name="sharp" ucd="stat.parameter">\n    <DESCRIPTION>\n     Sharpness of source\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="filefracday" datatype="long" name="filefracday" ucd="time.epoch;obs.exposure">\n    <DESCRIPTION>\n     Exposure file timestamp, with decimal representation\n     YYYYMMDDdddddd: year, month, day, and fractional day\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="field" datatype="int" name="field" ucd="meta.id;obs.field">\n    <DESCRIPTION>\n     Field ID\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="ccdid" datatype="unsignedByte" name="ccdid" ucd="meta.id;instr.det">\n    <DESCRIPTION>\n     CCD number (1..16)\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="qid" datatype="unsignedByte" name="qid" ucd="meta.id">\n    <DESCRIPTION>\n     Quadrant ID (1..4)\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="limitmag" datatype="float" name="limitmag" ucd="phot.mag;em.opt;stat.max;instr.sensitivity;obs.exposure" unit="mag">\n    <DESCRIPTION>\n     Approximate 5-sigma limiting magnitude corresponding to epoch-\n     based PSF-fit catalog\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="magzp" datatype="float" name="magzp" ucd="phot.mag;em.opt;phot.calib;arith.zp;obs.exposure" unit="mag">\n    <DESCRIPTION>\n     Magnitude zeropoint from photometric calibration\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="magzprms" datatype="float" name="magzprms" ucd="stat.rms;phot.mag;em.opt;phot.calib;arith.zp;obs.exposure" unit="mag">\n    <DESCRIPTION>\n     RMS deviation in magnitude zeropoint\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="clrcoeff" datatype="float" name="clrcoeff" ucd="stat ...
# #####################################################################################3
# b'<?xml version="1.0" encoding="utf-8"?>\n<!-- Produced with astropy.io.votable version 4.0.1.post1\n     http://www.astropy.org/ -->\n<VOTABLE version="1.4" xmlns="http://www.ivoa.net/xml/VOTable/v1.4" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:noNamespaceSchemaLocation="http://www.ivoa.net/xml/VOTable/v1.4">\n <RESOURCE type="results">\n  <TABLE>\n   <FIELD ID="oid" datatype="long" name="oid" ucd="meta.id">\n    <DESCRIPTION>\n     Object ID\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="expid" datatype="int" name="expid" ucd="meta.id;obs.exposure">\n    <DESCRIPTION>\n     Exposure ID\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="hjd" datatype="double" name="hjd" ucd="time.epoch" unit="d">\n    <DESCRIPTION>\n     Heliocentric Julian date (computed from mjd and the mean ra and\n     dec of the input catalog)\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="mjd" datatype="double" name="mjd" ucd="time.epoch;obs.exposure" unit="d">\n    <DESCRIPTION>\n     Modified Julian date\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="mag" datatype="float" name="mag" ucd="phot.mag;em.opt" unit="mag">\n    <DESCRIPTION>\n     Magnitude\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="magerr" datatype="float" name="magerr" ucd="stat.error;phot.mag;em.opt" unit="mag">\n    <DESCRIPTION>\n     Uncertainty in mag measurement. Includes correction to conform to\n     photometric repeatability RMS derived from "non-variable"\n     population.\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="catflags" datatype="int" name="catflags" ucd="meta.code">\n    <DESCRIPTION>\n     Catalog flags for source from PSF-fitting catalog\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="filtercode" arraysize="*" datatype="char" name="filtercode" ucd="instr.bandpass">\n    <DESCRIPTION>\n     Filter code (abbreviated name)\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="ra" datatype="double" name="ra" ucd="pos.eq.ra" unit="deg">\n    <DESCRIPTION>\n     Right Ascension of source\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="dec" datatype="double" name="dec" ucd="pos.eq.dec" unit="deg">\n    <DESCRIPTION>\n     Declination of source\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="chi" datatype="float" name="chi" ucd="stat.parameter">\n    <DESCRIPTION>\n     Chi-squared of source\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="sharp" datatype="float" name="sharp" ucd="stat.parameter">\n    <DESCRIPTION>\n     Sharpness of source\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="filefracday" datatype="long" name="filefracday" ucd="time.epoch;obs.exposure">\n    <DESCRIPTION>\n     Exposure file timestamp, with decimal representation\n     YYYYMMDDdddddd: year, month, day, and fractional day\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="field" datatype="int" name="field" ucd="meta.id;obs.field">\n    <DESCRIPTION>\n     Field ID\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="ccdid" datatype="unsignedByte" name="ccdid" ucd="meta.id;instr.det">\n    <DESCRIPTION>\n     CCD number (1..16)\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="qid" datatype="unsignedByte" name="qid" ucd="meta.id">\n    <DESCRIPTION>\n     Quadrant ID (1..4)\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="limitmag" datatype="float" name="limitmag" ucd="phot.mag;em.opt;stat.max;instr.sensitivity;obs.exposure" unit="mag">\n    <DESCRIPTION>\n     Approximate 5-sigma limiting magnitude corresponding to epoch-\n     based PSF-fit catalog\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="magzp" datatype="float" name="magzp" ucd="phot.mag;em.opt;phot.calib;arith.zp;obs.exposure" unit="mag">\n    <DESCRIPTION>\n     Magnitude zeropoint from photometric calibration\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="magzprms" datatype="float" name="magzprms" ucd="stat.rms;phot.mag;em.opt;phot.calib;arith.zp;obs.exposure" unit="mag">\n    <DESCRIPTION>\n     RMS deviation in magnitude zeropoint\n    </DESCRIPTION>\n   </FIELD>\n   <FIELD ID="clrcoeff" datatype="float" name="clrcoeff" ucd="stat ...

# %%
tabla = ascii.read(r.json()['curve_ztf']['841108100002803'],  format='csv', guess=False)
print(tabla)

# %%
#prueba
#url2 = 'http://127.0.0.1:5000/'
#r2 = requests.get(url2)
#curva_pan = r.json()['curve_pan']

# %%
if 'curve_pan' in catalogos:
    dtab_pan = pd.read_json(r.json()['curve_pan'])
    id2filter = np.array(list('grizy'))
    dtab_pan['filter'] = id2filter[(dtab_pan['filterID']-1)]
    dtab_pan.sort_values(by=['obsTime'])
    
    # convert flux in Jy to magnitudes
    t = dtab_pan['obsTime']
    mag = -2.5*np.log10(dtab_pan['psfFlux']) + 8.90
    xlim = np.array([t.min(),t.max()])
    xlim = xlim + np.array([-1,1])*0.02*(xlim[1]-xlim[0])

    pylab.rcParams.update({'font.size': 14})
    pylab.figure(1,(10,10))
    
    for i, filter in enumerate("grizy"):
        pylab.subplot(511+i)
        w = np.where(dtab_pan['filter']==filter)
            
        #pylab.plot(t[w],mag[w],'-o')

# %%
if 'curve_pan' in catalogos:
    dtab_pan = ascii.read(r.json()['curve_pan'])
    id2filter = np.array(list('grizy'))
    dtab_pan['filter'] = id2filter[(dtab_pan['filterID']-1).data]
    dtab_pan.sort('obsTime')
    
    # convert flux in Jy to magnitudes
    t = dtab_pan['obsTime']
    mag = -2.5*np.log10(dtab_pan['psfFlux']) + 8.90
    xlim = np.array([t.min(),t.max()])
    xlim = xlim + np.array([-1,1])*0.02*(xlim[1]-xlim[0])

    pylab.rcParams.update({'font.size': 14})
    pylab.figure(1,(10,10))
    for i, filter in enumerate("grizy"):
        pylab.subplot(511+i)
        w = np.where(dtab_pan['filter']==filter)
        pylab.plot(t[w],mag[w],'-o')
        pylab.ylabel(filter+' [mag]')
        pylab.xlim(xlim)
        pylab.gca().invert_yaxis()
    # if i==0:
       # pylab.title(objname)
    pylab.xlabel('Time [MJD]')
    pylab.tight_layout()
    #print(dtab)

# %%
if 'curve_ztf' in catalogos:
    dtab_ztf = ascii.read(r.json()['curve_ztf'])
    dtab_ztf.sort('oid')
    print(dtab_ztf)

# %%
asd = requests.get('https://irsa.ipac.caltech.edu/ibe/search/ztf/products/sci?POS=139.33444972,68.6350604')

# %%
ddd = requests.get('https://irsa.ipac.caltech.edu/ibe/search/ztf/products/sci?POS=139.33444972,68.6350604&WHERE=infobits<33554432')

# %%
tala = ascii.read(ddd.text, format = 'ipac')
if ddd.status_code != 200 :
    print(asds)

# %%
a = [1,3,4,5,6,7,4,1]
a.index(min(a))
